# %% [markdown]
# # 포스트 코로나 데이터 시각화 경진대회

# %%
import pandas as pd

# %% [markdown]
# ## 데이터 파악

# %% [markdown]
# ## adstrd_master : 행정동코드, 지역명 데이터

# %%
adstrd_master = pd.read_csv("adstrd_master.csv")
adstrd_master
# Out:
#       adstrd_code adstrd_nm  brtc_nm signgu_nm
# 0      11110515.0     청운효자동    서울특별시       종로구
# 1      11110530.0       사직동    서울특별시       종로구
# 2      11110540.0       삼청동    서울특별시       종로구
# 3      11110550.0       부암동    서울특별시       종로구
# 4      11110560.0       평창동    서울특별시       종로구
# ...           ...       ...      ...       ...
# 3488   50130580.0       서홍동  제주특별자치도      서귀포시
# 3489   50130590.0       대륜동  제주특별자치도      서귀포시
# 3490   50130600.0       대천동  제주특별자치도      서귀포시
# 3491   50130610.0       중문동  제주특별자치도      서귀포시
# 3492   50130620.0       예래동  제주특별자치도      서귀포시
#
# [3493 rows x 4 columns]

# %%
adstrd_master = adstrd_master.dropna()

# %%
adstrd_master
# Out:
#       adstrd_code adstrd_nm  brtc_nm signgu_nm
# 0      11110515.0     청운효자동    서울특별시       종로구
# 1      11110530.0       사직동    서울특별시       종로구
# 2      11110540.0       삼청동    서울특별시       종로구
# 3      11110550.0       부암동    서울특별시       종로구
# 4      11110560.0       평창동    서울특별시       종로구
# ...           ...       ...      ...       ...
# 3488   50130580.0       서홍동  제주특별자치도      서귀포시
# 3489   50130590.0       대륜동  제주특별자치도      서귀포시
# 3490   50130600.0       대천동  제주특별자치도      서귀포시
# 3491   50130610.0       중문동  제주특별자치도      서귀포시
# 3492   50130620.0       예래동  제주특별자치도      서귀포시
#
# [3474 rows x 4 columns]

# %%
adstrd_master.signgu_nm.unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구', '서구', '동구',
#        '영도구', '부산진구', '동래구', '남구', '북구', '해운대구', '사하구', '금정구', '연제구',
#        '수영구', '사상구', '기장군', '수성구', '달서구', '달성군', '미추홀구', '연수구', '남동구',
#        '부평구', '계양구', '강화군', '옹진군', '광산구', '유성구', '대덕구', '울주군', '수원시 장안구',
#        '수원시 권선구', '수원시 팔달구', '수원시 영통구', '성남시 수정구', '성남시 중원구', '성남시 분당구',
#        '의정부시', '안양시 만안구', '안양시 동안구', '부천시', '광명시', '평택시', '동두천시',
#        '안산시 상록구', '안산시 단원구', '고양시 덕양구', '고양시 일산동구', '고양시 일산서구', '과천시',
#        '구리시', '남양주시', '오산시', '시흥시', '군포시', '의왕시', '하남시', '용인시 처인구',
#        '용인시 기흥구', '용인시 수지구', '파주시', '이천시', '안성시', '김포시', '화성시', '광주시',
#        '양주시', '포천시', '여주시', '연천군', '가평군', '양평군', '춘천시', '원주시', '강릉시',
#        '동해시', '태백시', '속초시', '삼척시', '홍천군', '횡성군', '영월군', '평창군', '정선군',
# ...

# %%
sehwa_master = adstrd_master.loc[adstrd_master["signgu_nm"].str.contains("은평구|서대문구|마포구|종로구|용산구")].copy()
sehwa_master
# Out:
#      adstrd_code adstrd_nm brtc_nm signgu_nm
# 0     11110515.0     청운효자동   서울특별시       종로구
# 1     11110530.0       사직동   서울특별시       종로구
# 2     11110540.0       삼청동   서울특별시       종로구
# 3     11110550.0       부암동   서울특별시       종로구
# 4     11110560.0       평창동   서울특별시       종로구
# ..           ...       ...     ...       ...
# 217   11440700.0      망원2동   서울특별시       마포구
# 218   11440710.0       연남동   서울특별시       마포구
# 219   11440720.0      성산1동   서울특별시       마포구
# 220   11440730.0      성산2동   서울특별시       마포구
# 221   11440740.0       상암동   서울특별시       마포구
#
# [79 rows x 4 columns]

# %%
sehwa_master.to_csv("sehwa_master.csv", mode = 'w')

# %% [markdown]
# ## fpopl : 행정동별 유동인구 데이터
# - base_ymd: 기준년월일
# - tmzon_se_code: 24시간대 구분코드
# - sexdstn_se_code: 성별 구분코드 (M: 남성, F: 여성)
# - agrde_se_code: 5세단위 연령대구분코드 (단, age_00: 0세 ~ 9세, age_70: 70세 이상)
# - adstrd_code: 행정동코드
# - popltn_cascnt: 인구수

# %%
fpopl = pd.read_csv("fpopl.csv")

# %%
fpopl
# Out:
#           base_ymd  tmzon_se_code sexdstn_se_code agrde_se_code  adstrd_code  \
# 0         20200101              0               M        age_00     11650560
# 1         20200101              0               M        age_00     11590620
# 2         20200101              0               M        age_00     11560710
# 3         20200101              0               M        age_00     11470680
# 4         20200101              0               M        age_00     11350665
# ...            ...            ...             ...           ...          ...
# 47546438  20200616             23               F        age_70     11500593
# 47546439  20200616             23               M        age_70     11350624
# 47546440  20200616             23               M        age_70     11305534
# 47546441  20200616             23               F        age_70     11500604
# 47546442  20200616             23               F        age_70     11320514
#
#           popltn_cascnt
# ...

# %% [markdown]
# ## delivery: 배달 호출 정보 데이터

# %%
delivery = pd.read_csv("delivery.csv")

# %%
delivery
# Out:
#          SERIAL_NUMBER  PROCESS_DT DLVR_RQESTER_ID  DLVR_REQUST_STTUS_VALUE  \
# 0              4577985  2020-01-01         C000035                        1
# 1              4577986  2020-01-01         C000237                        1
# 2              4577988  2020-01-01         C000129                        1
# 3              4577989  2020-01-01         C000029                        1
# 4              4577991  2020-01-01         C000130                        1
# ...                ...         ...             ...                      ...
# 5158319       10672688  2020-06-21         C000312                        1
# 5158320       10672689  2020-06-21         C000026                        1
# 5158321       10672690  2020-06-21         C000130                        1
# 5158322       10672691  2020-06-21         C000237                        1
# 5158323       10672692  2020-06-21         C000209                        1
#
# ...

# %%
delivery.DLVR_STORE_SIGUNGU.unique()
# Out:
# array(['창원시 마산회원구', '광명시', '은평구', '의정부시', '고양시 덕양구', '부천시', '구로구', '영등포구',
#        '광양시', '수성구', '고양시 일산동구', '서산시', '서귀포시', '군산시', '금천구', '포천시',
#        '동두천시', '진주시', '화성시', '안산시 상록구', '영천시', '노원구', '안양시 동안구', '평택시',
#        '부평구', '도봉구', '순천시', '양천구', '동작구', '서구', '시흥시', '창원시 마산합포구', '경산시',
#        '동구', '고양시 일산서구', '강서구', '달서구', '제천시', '북구', '보령시', '관악구', '원주시',
#        '안동시', '남양주시', '수원시 권선구', '파주시', '김포시', '나주시', '서대문구', '달성군',
#        '여수시', '용인시 처인구', '광주시', '양주시', '칠곡군', '연천군', '청주시 청원구', '해운대구',
#        '영주시', '경주시', '수원시 팔달구', '음성군', '성남시 수정구', '김천시', '문경시', '서초구',
#        '성남시 중원구', '아산시', '논산시'], dtype=object)

# %%
sehwa_delivery = delivery.loc[delivery["DLVR_STORE_SIGUNGU"].str.contains("은평구|서대문구|마포구|종로구|용산구")].copy()
sehwa_delivery
# Out:
#          SERIAL_NUMBER  PROCESS_DT DLVR_RQESTER_ID  DLVR_REQUST_STTUS_VALUE  \
# 2              4577988  2020-01-01         C000129                        1
# 133            4578143  2020-01-01         C000129                        1
# 169            4578187  2020-01-01         C000129                        1
# 177            4578195  2020-01-01         C000129                        1
# 183            4578201  2020-01-01         C000129                        1
# ...                ...         ...             ...                      ...
# 5157761       10672047  2020-06-21         C000129                        1
# 5157825       10672121  2020-06-21         C000129                        1
# 5157891       10672197  2020-06-21         C000129                        1
# 5158233       10672586  2020-06-21         C000129                        1
# 5158277       10672639  2020-06-21         C000129                        1
#
# ...

# %%
sehwa_delivery.to_csv("sehwa_delivery.csv", mode = 'w')

# %%
delivery.columns
# Out:
# Index(['SERIAL_NUMBER', 'PROCESS_DT', 'DLVR_RQESTER_ID',
#        'DLVR_REQUST_STTUS_VALUE', 'DLVR_RCEPT_CMPNY_ID', 'DLVR_STORE_ID',
#        'DLVR_STORE_INDUTY_NM', 'DLVR_STORE_LEGALDONG_CODE', 'DLVR_STORE_SIDO',
#        'DLVR_STORE_SIGUNGU', 'DLVR_STORE_DONG', 'DLVR_STORE_RI',
#        'DLVR_STORE_ADSTRD_CODE', 'DLVR_STORE_RDNMADR_CODE',
#        'DLVR_DSTN_LEGALDONG_CODE', 'DLVR_DSTN_SIDO', 'DLVR_DSTN_SIGUNGU',
#        'DLVR_DSTN_DONG', 'DLVR_DSTN_RI', 'DLVR_DSTN_ADSTRD_CODE',
#        'DLVR_DSTN_RDNMADR_CODE', 'DLVR_MAN_ID', 'DLVR_AMOUNT',
#        'CALL_RLAY_FEE_AMOUNT', 'GOODS_AMOUNT', 'SETLE_KND_VALUE',
#        'SETLE_CARD_CN', 'DLVR_RCEPT_TIME', 'DLVR_CARALC_TIME',
#        'DLVR_COMPT_TIME', 'DLVR_CANCL_TIME'],
#       dtype='object')

# %% [markdown]
# ## card: 업종 별 결제금액 데이터

# %%
card = pd.read_csv("card_20200717.csv")
card
# Out:
#          receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0            20200104   1174066000      성내3동                  7041
# 1            20200104   1174066000      성내3동                  7022
# 2            20200104   1174066000      성내3동                  7021
# 3            20200104   1174066000      성내3동                  7020
# 4            20200104   1174066000      성내3동                  6110
# ...               ...          ...       ...                   ...
# 3713947      20200614   1121586000      구의2동                  4004
# 3713948      20200614   1121584700      자양4동                  9010
# 3713949      20200614   1162052500      보라매동                  6140
# 3713950      20200614   1135056000      월계1동                  9998
# 3713951      20200614   1159060500       흑석동                  9204
#
#         mrhst_induty_cl_nm  selng_cascnt   salamt
# 0                       약국           463  5843230
# 1                     치과의원            33  7835550
# ...

# %%
card_seoul = pd.read_csv("card_seoul_health.csv")

# %%
card_seoul_food = card_seoul.drop(["Unnamed: 0"], axis=1)

# %%
card.adstrd_nm.unique()
# Out:
# array(['성내3동', '성내2동', '성내1동', '천호3동', '천호2동', '천호1동', '암사3동', '암사2동',
#        '암사1동', '고덕2동', '고덕1동', '명일2동', '명일1동', '상일동', '강일동', '잠실7동',
#        '잠실6동', '잠실4동', '잠실3동', '잠실2동', '잠실본동', '위례동', '장지동', '문정2동',
#        '문정1동', '가락2동', '가락1동', '가락본동', '삼전동', '석촌동', '송파2동', '송파1동',
#        '오금동', '오륜동', '방이2동', '방이1동', '마천2동', '마천1동', '거여2동', '거여1동',
#        '풍납2동', '풍납1동', '수서동', '일원2동', '일원1동', '일원본동', '세곡동', '개포4동',
#        '개포2동', '도곡2동', '도곡1동', '역삼2동', '역삼1동', '대치4동', '대치2동', '대치1동',
#        '삼성2동', '삼성1동', '청담동', '압구정동', '논현2동', '논현1동', '신사동', '내곡동',
#        '양재2동', '양재1동', '방배4동', '방배3동', '방배2동', '방배1동', '방배본동', '반포4동',
#        '반포3동', '반포2동', '반포1동', '반포본동', '잠원동', '서초4동', '서초3동', '서초2동',
#        '서초1동', '난곡동', '미성동', '삼성동', '대학동', '조원동', '난향동', '신림동', '서림동',
#        '신원동', '서원동', '남현동', '인헌동', '중앙동', '은천동', '청룡동', '낙성대동', '행운동',
#        '성현동', '청림동', '보라매동', '신대방2동', '신대방1동', '대방동', '사당5동', '사당4동',
# ...

# %%
sehwa_card = card.loc[card["sigungu"].str.contains("은평구|서대문구|마포구|종로구|용산구")].copy()
sehwa_card

# %% [markdown]
# ## Index: 품목 별 소비지수 데이터

# %%
index = pd.read_csv("/Volumes/Passport/Data/Post_Corona/KT_data_20200703/index.csv")
index
# Out:
#         period     catl    catm  age gender sido sigungu         cgi
# 0       201901  건강/의료용품  건강관리용품   20      F   서울     관악구  115.374642
# 1       201901  건강/의료용품  건강관리용품   20      F   서울     광진구  119.596454
# 2       201901  건강/의료용품  건강관리용품   20      F   서울     도봉구  156.992847
# 3       201901  건강/의료용품  건강관리용품   20      F   서울     동작구   58.342726
# 4       201901  건강/의료용품  건강관리용품   20      F   서울     마포구  145.147595
# ...        ...      ...     ...  ...    ...  ...     ...         ...
# 127520  202005      화장품     화장품  all    all   서울     강서구   51.365660
# 127521  202005      화장품     화장품  all    all   서울     관악구   61.997865
# 127522  202005      화장품     화장품  all    all   서울     금천구   82.198402
# 127523  202005      화장품     화장품  all    all   서울     도봉구   35.875600
# 127524  202005      화장품     화장품  all    all   서울     용산구   45.569377
#
# [127525 rows x 8 columns]

# %%
index.catl.unique()
# Out:
# array(['건강/의료용품', '식품', '일용품', '화장품'], dtype=object)

# %%
index.sigungu.unique()
# Out:
# array(['관악구', '광진구', '도봉구', '동작구', '마포구', '성북구', '용산구', 'all', '강동구',
#        '강서구', '금천구', '동대문구', '서대문구', '송파구', '종로구', '양천구', '영등포구', '은평구',
#        '강북구', '구로구', '강남구', '노원구', '서초구', '중랑구', '중구', '성동구'],
#       dtype=object)

# %% [markdown]
# ## 서북권 + 도심권 : 은평,서대문,마포,종로,중,용산

# %%
eunpyung = index[index["sigungu"] == "은평구"]
seodaemun = index[index["sigungu"] == "서대문구"]
mapo = index[index["sigungu"] == "마포구"]
jongro = index[index["sigungu"] == "종로구"]
yongsan = index[index["sigungu"] == "용산구"]

seobuk = [eunpyung, seodaemun, mapo, jongro, yongsan]

def count_each(lst):
    for i in (lst):
        print(i.count())
       
count_each(seobuk)

def sum_everything(lst):
    count = 0
    for i in (lst):
# Out:
# period     4896
# catl       4896
# catm       4896
# age        4896
# gender     4896
# sido       4896
# sigungu    4896
# cgi        4896
# dtype: int64
# period     4893
# catl       4893
# catm       4893
# age        4893
# gender     4893
# sido       4893
# sigungu    4893
# cgi        4893
# dtype: int64
# period     4893
# catl       4893
# catm       4893
# age        4893
# gender     4893
# sido       4893
# sigungu    4893
# cgi        4893
# dtype: int64
# period     4877
# catl       4877
# catm       4877
# age        4877
# gender     4877
# sido       4877
# sigungu    4877
# cgi        4877
# dtype: int64
# period     4892
# catl       4892
# catm       4892
# age        4892
# gender     4892
# sido       4892
# sigungu    4892
# cgi        4892
# dtype: int64

# %%
sehwa_index = index.loc[index["sigungu"].str.contains("은평구|서대문구|마포구|종로구|용산구")].copy()
sehwa_index
# Out:
#         period     catl    catm  age gender sido sigungu         cgi
# 4       201901  건강/의료용품  건강관리용품   20      F   서울     마포구  145.147595
# 6       201901  건강/의료용품  건강관리용품   20      F   서울     용산구   14.137181
# 13      201901  건강/의료용품  건강관리용품   20      M   서울     마포구  105.951146
# 14      201901  건강/의료용품  건강관리용품   20      M   서울    서대문구   93.004778
# 16      201901  건강/의료용품  건강관리용품   20      M   서울     종로구   85.537946
# ...        ...      ...     ...  ...    ...  ...     ...         ...
# 127498  202005      화장품    뷰티소품  all      M   서울     은평구   76.752918
# 127504  202005      화장품    뷰티소품  all    all   서울     용산구   45.003538
# 127505  202005      화장품    뷰티소품  all    all   서울     은평구   62.254066
# 127519  202005      화장품     화장품  all      M   서울     종로구   38.739734
# 127524  202005      화장품     화장품  all    all   서울     용산구   45.569377
#
# [24451 rows x 8 columns]

# %%
sehwa_index.to_csv("sehwa_index", mode = 'w')

# %% [markdown]
# ## 서북권, 도심권 데이터만 살펴보기

# %%
delivery = pd.read_csv("sehwa_delivery.csv")
delivery
# Out:
#        Unnamed: 0  SERIAL_NUMBER  PROCESS_DT DLVR_RQESTER_ID  \
# 0               2        4577988  2020-01-01         C000129
# 1             133        4578143  2020-01-01         C000129
# 2             169        4578187  2020-01-01         C000129
# 3             177        4578195  2020-01-01         C000129
# 4             183        4578201  2020-01-01         C000129
# ...           ...            ...         ...             ...
# 57899     5157761       10672047  2020-06-21         C000129
# 57900     5157825       10672121  2020-06-21         C000129
# 57901     5157891       10672197  2020-06-21         C000129
# 57902     5158233       10672586  2020-06-21         C000129
# 57903     5158277       10672639  2020-06-21         C000129
#
#        DLVR_REQUST_STTUS_VALUE DLVR_RCEPT_CMPNY_ID DLVR_STORE_ID  \
# 0                            1             C000129      S0025740
# 1                            1             C000129      S0003051
# ...

# %%
index = pd.read_csv("sehwa_index.csv")
index
# Out:
#        Unnamed: 0  period     catl    catm  age gender sido sigungu  \
# 0               4  201901  건강/의료용품  건강관리용품   20      F   서울     마포구
# 1               6  201901  건강/의료용품  건강관리용품   20      F   서울     용산구
# 2              13  201901  건강/의료용품  건강관리용품   20      M   서울     마포구
# 3              14  201901  건강/의료용품  건강관리용품   20      M   서울    서대문구
# 4              16  201901  건강/의료용품  건강관리용품   20      M   서울     종로구
# ...           ...     ...      ...     ...  ...    ...  ...     ...
# 24446      127498  202005      화장품    뷰티소품  all      M   서울     은평구
# 24447      127504  202005      화장품    뷰티소품  all    all   서울     용산구
# 24448      127505  202005      화장품    뷰티소품  all    all   서울     은평구
# 24449      127519  202005      화장품     화장품  all      M   서울     종로구
# 24450      127524  202005      화장품     화장품  all    all   서울     용산구
#
#               cgi
# 0      145.147595
# 1       14.137181
# 2      105.951146
# 3       93.004778
# 4       85.537946
# ...           ...
# ...

# %%
index.catl.unique()
# Out:
# array(['건강/의료용품', '식품', '일용품', '화장품'], dtype=object)

# %%
index.catm.unique()
# Out:
# array(['건강관리용품', '가공식품', '기호식품', '담배', '빙과류', '빵류', '신선식품', '유제품류', '음료',
#        '제과류', '주류', '생활용품', '애완동물용품', '바디/헤어용품', '뷰티소품', '화장품'],
#       dtype=object)

# %%
index.gender.unique()
# Out:
# array(['F', 'M', 'all'], dtype=object)

# %%
index.gender.unique
# Out:
# ----------------------------------------------------------------
# AttributeError                 Traceback (most recent call last)
# <ipython-input-11-d1b42e050876> in <module>
# ----> 1 index.gender.unique.count()
#
# AttributeError: 'function' object has no attribute 'count'
